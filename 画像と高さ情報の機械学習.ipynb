# %% [markdown]
# <a href="https://colab.research.google.com/github/shimiiizu/CNN/blob/main/%E7%94%BB%E5%83%8F%E3%81%A8%E9%AB%98%E3%81%95%E6%83%85%E5%A0%B1%E3%81%AE%E6%A9%9F%E6%A2%B0%E5%AD%A6%E7%BF%92.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 事前に64×64にカットした画像情報と高さ情報のMax値のリスト(height_max_list)が必要

# (1000,64,64,3)のndarray（画像）を作成
# (1000,)のdnarray（高さ）を作成

# 画像情報をX、高さ情報をyとしてモデルを学習する

# %%
#　画像情報と高さ情報のMax値のリストを読み込む
import pandas as pd

df = pd.read_csv('./height_max_list.csv')

df
# Out:
#    Unnamed: 0                file_name  max_height
# 0           0   height_cut_test0_1.csv     1315204
# 1           1  height_cut_test0_0 .csv     1324925

# %%
# file_nameを画像ファイル名に変換する

for i in df['file_name']:
  print(str(i))
  print(str(i[:-4]))
  print(str(i[:-4]+'.jpg'))
# Out:
# height_cut_test0_1.csv
# height_cut_test0_1
# height_cut_test0_1.jpg
# height_cut_test0_0 .csv
# height_cut_test0_0
# height_cut_test0_0 .jpg

# %%
# 画像のリストを作成する

image_list = []

# %%
# 機械学習の準備

import tensorflow as tf
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense
from tensorflow.keras.models import Sequential
from sklearn.model_selection import train_test_split
import numpy as np

# %%
# 学習用のデータの生成

X =
